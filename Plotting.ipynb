# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("result.csv").query('associativity == 2 & input == "blackscholes_four-blackscholes" & blocksize == 32')[['protocol', 'cachesize', 'exec']]
f = sns.catplot(data=df, x='cachesize', y='exec', hue='protocol', linestyles=["--", "--", "--"], kind="point", hue_order=['Dragon', 'MESI', 'MOESI'])
f.set(yscale="log")

# %%
f.savefig("cachesize-blackscholes.png", dpi=600)

# %%
df = pd.read_csv("result.csv").query('associativity == 2 & input == "bodytrack_four-bodytrack" & blocksize == 32')[['protocol', 'cachesize', 'exec']]
f = sns.catplot(data=df, x='cachesize', y='exec', hue='protocol', linestyles=["--", "--", "--"], kind="point", hue_order=['Dragon', 'MESI', 'MOESI'])
f.set(yscale="log")

# %%
f.savefig("cachesize-bodytrack.png", dpi=600)

# %%
df = pd.read_csv("result.csv").query('associativity == 2 & input == "fluidanimate_four-fluidanimate" & blocksize == 32')[['protocol', 'cachesize', 'exec']]
f = sns.catplot(data=df, x='cachesize', y='exec', hue='protocol', linestyles=["--", "--", "--"], kind="point", hue_order=['Dragon', 'MESI', 'MOESI'])
f.set(yscale="log")

# %%
f.savefig("cachesize-fluidanimate.png", dpi=600)

# %%
df = pd.read_csv("result.csv").query('cachesize == 4096 & associativity == 2 & input == "blackscholes_four-blackscholes"')[['protocol', 'blocksize', 'exec']]
f = sns.catplot(data=df, x='blocksize', y='exec', hue='protocol', linestyles=["--", "--", "--"], kind="point", hue_order=['Dragon', 'MESI', 'MOESI'])
f.set(yscale="log")

# %%
df = pd.read_csv("result.csv").query('cachesize == 4096 & associativity == 2 & input == "bodytrack_four-bodytrack"')[['protocol', 'blocksize', 'exec']]
f = sns.catplot(data=df, x='blocksize', y='exec', hue='protocol', linestyles=["--", "--", "--"], kind="point", hue_order=['Dragon', 'MESI', 'MOESI'])
f.set(yscale="log")

# %%
df = pd.read_csv("result.csv").query('cachesize == 4096 & associativity == 2 & input == "fluidanimate_four-fluidanimate"')[['protocol', 'blocksize', 'exec']]
f = sns.catplot(data=df, x='blocksize', y='exec', hue='protocol', linestyles=["--", "--", "--"], kind="point", hue_order=['Dragon', 'MESI', 'MOESI'])
f.set(yscale="log")
