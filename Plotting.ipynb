# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("result.csv").query('associativity == 2 & input == "blackscholes_four-blackscholes" & blocksize == 32')[['protocol', 'cachesize', 'exec']]
f = sns.catplot(data=df, x='cachesize', y='exec', hue='protocol', linestyles=["--", "--", "--"], kind="point")
f.set(yscale="log")

# %%
df = pd.read_csv("result.csv").query('associativity == 2 & input == "blackscholes_four-blackscholes" & blocksize == 32')[['protocol', 'cachesize', 'exec']]
df
# Out:
#      protocol  cachesize       exec
# 444      MESI       1024   97462076
# 468      MESI        512  269784355
# 923    Dragon      32768   31099486
# 1017   Dragon       4096   26957202
# 1190    MOESI        128  669388741
# 1276    MOESI        256  474417132
# 1729     MESI      32768   18257950
# 2388    MOESI        512  269605212
# 2678    MOESI       4096   24151897
# 2811     MESI       8192   20091565
# 2914    MOESI      32768   18252220
# 3102     MESI        128  674577278
# 3161     MESI        256  474414388
# 3250     MESI       2048   45886106
# 3817    MOESI       2048   46071836
# 3874    MOESI      16384   19383654
# 4420   Dragon       1024  142701969
# 4442   Dragon        512  340924809
# 4794     MESI         64  743774596
# 4820    MOESI         64  746240720
# 5112    MOESI       8192   20124151
# 5225     MESI       4096   24163602
# 5932   Dragon       8192   23641941
# 6013   Dragon         64  753806340
# 6449     MESI      16384   19453621
# 6608    MOESI       1024   97445850
# 7159   Dragon       2048   61134215
# 7169   Dragon      16384   33771568
# 7280   Dragon        256  534306622
# 7316   Dragon        128  695723480
